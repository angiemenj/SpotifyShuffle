# %% [markdown]
# # Final Project (Individual)
#
# #### Each Each student picks a project assigned at the beginning of the course and will prepare a case study on a chosen topic. There are two tracks for the project. Student, based on personal interest will choose one of the two  tracks. The project output at the end of the course will be a paper describing the case prepared and a presentation to the class.
#
# #### Business Application Track: In this track, the student plays a role of a business consultant addressing a serious business issue and presents a solution that addresses the issue using Machine Learning. The student will choose one out of three choice business problems given during the beginning of the course. The student will apply the learnings from the course supplemented by research to analyze the problem and provide a recommendation that addresses it using Machine Learning.

# %%
import pandas as pd

# %%
spotifydata = pd.read_excel('\\Users\Angie Menjivar\Downloads\YourLibrary (1).xlsx')

# %%
spotifydata
# Out:
#                  artist                  album  \
# 0          Moneybagg Yo       A Gangsta’s Pain
# 1                Future      I NEVER LIKED YOU
# 2                 Drake    Certified Lover Boy
# 3          Lil Uzi Vert          Luv Is Rage 2
# 4     Hermanos Figueroa            The Line Up
# ...                 ...                    ...
# 2822      Bryson Tiller  A N N I V E R S A R Y
# 2823                SZA                    SOS
# 2824   Trinidad Cardona                Even If
# 2825      Natanael Cano                Gracias
# 2826           Lil Baby            Drip Harder
#
#                                         track  \
# 0                                    Projects
# 1                           PUFFIN ON ZOOTIEZ
# 2       Way 2 Sexy (with Future & Young Thug)
# 3                                      20 Min
# 4                                Buen Ejemplo
# ...                                       ...
# 2822                              Years Go By
# 2823                                    Blind
# 2824                                  Even If
# 2825                                  Gracias
# 2826  Never Recover (Lil Baby & Gunna, Drake)
#
#                                        uri      artist.1  \
# 0     spotify:track:0iknSgwfDslqMT5pr6j5zi         Drake
# 1     spotify:track:1qMMYpVatbRITKCfq1gasi     Bad Bunny
# 2     spotify:track:0k1WUmIRnG3xU6fvvDVfRG         Flume
# 3     spotify:track:0uxSUdBrJy9Un0EYoBowng         Flume
# 4     spotify:track:3c1JN0VTTXdZQ6qhqlToqe  Prince Royce
# ...                                    ...           ...
# 2822  spotify:track:4SVTus5gJc5cfkFZ8ELK1p           NaN
# 2823  spotify:track:2CSRrnOEELmhpq8iaAi9cd           NaN
# 2824  spotify:track:2JFz42odEoDq6TNgrtbe1g           NaN
# 2825  spotify:track:4lkl1CC0Py1pLOuQ4h2KuV           NaN
# 2826  spotify:track:6wWaVoUOzLQJHd3bWAUpdZ           NaN
#
#                                    album.1  \
# 0     If You're Reading This It's Too Late
# 1                 EL ÚLTIMO TOUR DEL MUNDO
# 2                                  Palaces
# 3                         Hi This Is Flume
# 4              Adicto (feat. Marc Anthony)
# ...                                    ...
# 2822                                   NaN
# 2823                                   NaN
# 2824                                   NaN
# 2825                                   NaN
# 2826                                   NaN
#
#                                      uri.1  Unnamed: 7  Unnamed: 8  \
# 0     spotify:album:0ptlfJfwGTy0Yvrk14JK1I         NaN         NaN
# 1     spotify:album:2d9BCZeAAhiZWPpbX9aPCW         NaN         NaN
# 2     spotify:album:0XzZkJXmgnY3o2LbuPYmQg         NaN         NaN
# 3     spotify:album:2Vx9FC6Um8i6kEtY7HNswB         NaN         NaN
# 4     spotify:album:3WkWeNvKY4CMeLwKIeOugQ         NaN         NaN
# ...                                    ...         ...         ...
# 2822                                   NaN         NaN         NaN
# 2823                                   NaN         NaN         NaN
# 2824                                   NaN         NaN         NaN
# 2825                                   NaN         NaN         NaN
# 2826                                   NaN         NaN         NaN
#
#       Unnamed: 9             name                                  uri.2  \
# 0            NaN        Bad Bunny  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 1            NaN  Benito Martínez  spotify:artist:6OxQzDvWTwU1YJodamfyvY
# 2            NaN        DR. GABBA  spotify:artist:0PBXAVipMP5B7A554hJX0R
# 3            NaN            Flume  spotify:artist:6nxWCVXbOlEVRexSbLsTer
# 4            NaN           Maluma  spotify:artist:1r4hJ1h58CWwUQe3MxPuau
# ...          ...              ...                                    ...
# 2822         NaN              NaN                                    NaN
# 2823         NaN              NaN                                    NaN
# 2824         NaN              NaN                                    NaN
# 2825         NaN              NaN                                    NaN
# 2826         NaN              NaN                                    NaN
#
#       Unnamed: 12                                        Unnamed: 13
# 0             NaN  spotify:local:::trevor+daniel+-+falling+%5Bslo...
# 1             NaN  spotify:local:::Travis+Scott%2C+Kaash+Paige%2C...
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ...           ...                                                ...
# 2822          NaN                                                NaN
# 2823          NaN                                                NaN
# 2824          NaN                                                NaN
# 2825          NaN                                                NaN
# 2826          NaN                                                NaN
#
# [2827 rows x 14 columns]

# %%
spotifydata.columns
# Out:
# Index(['artist', 'album', 'track', 'uri', 'artist.1', 'album.1', 'uri.1',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'name', 'uri.2',
#        'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
spotlist = list(spotifydata)
print(spotlist)
# Out:
# ['artist', 'album', 'track', 'uri', 'artist.1', 'album.1', 'uri.1', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'name', 'uri.2', 'Unnamed: 12', 'Unnamed: 13']

# %%
spotifydata.count()
# Out:
# artist         2827
# album          2827
# track          2827
# uri            2827
# artist.1         18
# album.1          18
# uri.1            18
# Unnamed: 7        0
# Unnamed: 8        0
# Unnamed: 9        0
# name              7
# uri.2             7
# Unnamed: 12       0
# Unnamed: 13       2
# dtype: int64

# %%
spotifydata.isnull().sum()
# Out:
# artist            0
# album             0
# track             0
# uri               0
# artist.1       2809
# album.1        2809
# uri.1          2809
# Unnamed: 7     2827
# Unnamed: 8     2827
# Unnamed: 9     2827
# name           2820
# uri.2          2820
# Unnamed: 12    2827
# Unnamed: 13    2825
# dtype: int64

# %%
# taking out unnecessary columns
spotdata = spotifydata.drop(columns=['artist.1', 'album.1', 'uri.1','Unnamed: 7','Unnamed: 8', 'Unnamed: 9', 'name',
                            'uri.2','Unnamed: 12', 'Unnamed: 13'])
spotdata.count()
# Out:
# artist    2827
# album     2827
# track     2827
# uri       2827
# dtype: int64

# %%
spotdata
# Out:
#                  artist                  album  \
# 0          Moneybagg Yo       A Gangsta’s Pain
# 1                Future      I NEVER LIKED YOU
# 2                 Drake    Certified Lover Boy
# 3          Lil Uzi Vert          Luv Is Rage 2
# 4     Hermanos Figueroa            The Line Up
# ...                 ...                    ...
# 2822      Bryson Tiller  A N N I V E R S A R Y
# 2823                SZA                    SOS
# 2824   Trinidad Cardona                Even If
# 2825      Natanael Cano                Gracias
# 2826           Lil Baby            Drip Harder
#
#                                         track  \
# 0                                    Projects
# 1                           PUFFIN ON ZOOTIEZ
# 2       Way 2 Sexy (with Future & Young Thug)
# 3                                      20 Min
# 4                                Buen Ejemplo
# ...                                       ...
# 2822                              Years Go By
# 2823                                    Blind
# 2824                                  Even If
# 2825                                  Gracias
# 2826  Never Recover (Lil Baby & Gunna, Drake)
#
#                                        uri
# 0     spotify:track:0iknSgwfDslqMT5pr6j5zi
# 1     spotify:track:1qMMYpVatbRITKCfq1gasi
# 2     spotify:track:0k1WUmIRnG3xU6fvvDVfRG
# 3     spotify:track:0uxSUdBrJy9Un0EYoBowng
# 4     spotify:track:3c1JN0VTTXdZQ6qhqlToqe
# ...                                    ...
# 2822  spotify:track:4SVTus5gJc5cfkFZ8ELK1p
# 2823  spotify:track:2CSRrnOEELmhpq8iaAi9cd
# 2824  spotify:track:2JFz42odEoDq6TNgrtbe1g
# 2825  spotify:track:4lkl1CC0Py1pLOuQ4h2KuV
# 2826  spotify:track:6wWaVoUOzLQJHd3bWAUpdZ
#
# [2827 rows x 4 columns]

# %%
track = spotdata.track

# %%
track
# Out:
# 0                                      Projects
# 1                             PUFFIN ON ZOOTIEZ
# 2         Way 2 Sexy (with Future & Young Thug)
# 3                                        20 Min
# 4                                  Buen Ejemplo
#                          ...
# 2822                                Years Go By
# 2823                                      Blind
# 2824                                    Even If
# 2825                                    Gracias
# 2826    Never Recover (Lil Baby & Gunna, Drake)
# Name: track, Length: 2827, dtype: object

# %%
import random

# Define a prediction model (in this case, a random shuffle)
def predict_next_song(current_song, track):
    next_song = random.choice(track)
    while next_song == current_song:
        next_song = random.choice(track)
    return next_song

# Shuffle the playlist by predicting the next song
current_song = None
shuffled_playlist = []
for i in range(len(track)):
    next_song = predict_next_song(current_song, track)
    shuffled_playlist.append(next_song)
    current_song = next_song

# Print the shuffled playlist
shuffled_playlist
# Out:
# ['Bien Arrebatao',
#  'CHARLIE',
#  'Yo x Ti, Tu x Mi',
#  'L.N.E.M. (GATA) (feat. Kapla y Miky, Philip Ariaz & Blessd)',
#  'Traicionera',
#  'Childs Play',
#  'Prices',
#  "Why DON'T You LOVE me?",
#  'Brisa',
#  'Blue Tint',
#  'Pikete',
#  'GOD.',
#  'Don’t Break My Heart',
#  'Perriando',
#  'If I Ruled the World (Imagine That) (feat. Lauryn Hill)',
#  'Santorini',
#  'Better Things',
#  'Hype',
#  'Después de la Playa',
#  'No Es Normal',
#  '25/8',
#  'WHATS POPPIN',
#  'What’s New',
#  'Feds',
#  'Buckets (feat. Future) - From SR3MM',
#  'Lovers Anonymous',
#  'A La Perfección',
#  'Flow HP',
#  'Inmortal',
#  'Free',
#  'Ansiedad',
#  'SORRY PAPI',
#  '1 Thot 2 Thot Red Thot Blue Thot',
#  'Safaera',
#  'Pose (feat. Lil Uzi Vert)',
#  'Pass It (feat. G-Eazy)',
#  'Perreo Intenso',
#  'Survival',
#  'Un Polvo (feat. Bad Bunny, Arcángel, Ñengo Flow & De La Ghetto)',
#  'Eres Mía',
#  'La Forma en Que Me Miras',
#  'Cucumber Water',
#  'Baby',
#  'honey baby (SPOILED!)',
#  'DeLorean',
#  'Everybody',
#  'Un Ratito',
#  'On BS',
#  'No Complaints',
#  'Dimelo',
#  'Killing Me Softly With His Song',
#  'Heavy (with Lil Uzi Vert)',
#  'Got Friends',
#  'Celebrate (feat. Travis Scott & Post Malone)',
#  'True Love',
#  "No Tellin'",
#  'Thank You (ft. Lucy Rose & The RattPack)',
#  'PRIDE.',
#  'CAROUSEL',
#  'Splashin',
#  'Si te Vas - The Remix',
#  'Tumbados En Miami',
#  'Focus (feat. 21 Savage)',
#  'Lo Que Necesitas',
#  "Llamé Pa' Verte (Bailando Sexy)",
#  "Pa' Que La Pases Bien",
#  'Vete',
#  'Before I Die',
#  'Still',
#  'Take Me Away (From Freaky Friday)',
#  'ESTILAZO',
#  'Sólo Amigos',
#  'She For Keeps',
#  '3',
#  'Calling My Spirit',
#  'Beautiful',
#  'Back To Sleep',
#  'Dale',
#  'Culture National Anthem - Outro',
#  'Randy Johnson',
#  'Sweet Thangs',
#  'Mercedes',
#  'Gave Your Love Away',
#  'GREECE (feat. Drake)',
#  'Atrapado en un Sueño',
#  'Wrong Decisions',
#  'Dime Tu',
#  'DadBod',
#  'First Off (feat. Travis Scott)',
#  "Can't Get Enough",
#  'In Da Getto',
#  'GOOBA',
#  'Outside Today',
#  'Después de la Playa',
#  'GUMMO',
#  'Couch',
#  'Out of Time',
#  'GRACIAS POR NADA',
#  'Muévelo Lento',
#  'GRACIAS POR NADA',
#  'El Respaldo',
#  'Like a Tattoo',
#  'BOOKER T',
#  'HUMBLE.',
#  'Race My Mind',
#  'Un Verano Sin Ti',
#  "Oodles O' Noodles Babies",
#  'DARK BROTHERHOOD (feat. Lil Baby)',
#  'Essence (feat. Justin Bieber & Tems)',
#  'Taking Chances',
#  'NO MÁS (feat. Quavo, J. Balvin, Anitta, and Pharrell)',
#  'What You Know',
#  'La Cama - Remix',
#  'Trust Issues',
#  '18 Months (feat. Ty Dolla $ign)',
#  'Champagne Shots',
#  'Ya Digg',
#  'PANTIES Y BRASIERES',
#  'Nights',
#  'Blow',
#  'Kill Them All',
#  'NO SNITCHING (with Dusty Locane)',
#  'Miss Independent',
#  'Keep Calling',
#  'Be Your Girl (Kaytranada Edition)',
#  'PASS OUT (feat. 21 Savage)',
#  'Saint Laurent Mask',
#  'Pussy & Millions (feat. Travis Scott)',
#  'Bonita',
#  'Feel',
#  'STOP TRYING TO BE GOD',
#  'Fantastic',
#  'The Tip Out',
#  'Fin',
#  'PICK IT UP (feat. A$AP Rocky)',
#  'Diamantes en Mis Dientes',
#  'Vitality',
#  'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)',
#  'Overnight',
#  'SORRY PAPI',
#  'EARFQUAKE',
#  'Zendaya (feat. J. Cole)',
#  'Bring You Down',
#  "Can't Have Everything",
#  'Last Call',
#  'Sold Out Dates (feat. Lil Baby)',
#  'Sexo Sin Titulo (feat. Jay Wheeler & Lenny Tavárez)',
#  'Mentiras',
#  'Take Me Away',
#  'LOYALTY. FEAT. RIHANNA.',
#  'Perfect',
#  'Iridescent',
#  'The Motion',
#  'Betrayal (feat. Drake)',
#  "Everybody's Gotta Learn Sometime",
#  'Winnie Pooh',
#  'Holdin On',
#  'Rick & Morty',
#  'Taking A Walk',
#  "Where's The Catch? (feat. André 3000)",
#  'Snow White',
#  'Feeling Myself Today',
#  'Sign of the Times',
#  'Brag (feat. Fivio Foreign)',
#  'Eye 2 Eye',
#  'Said Sum (feat. City Girls & DaBaby) - Remix',
#  'Faith (feat. Quavo)',
#  'Como Antes',
#  'PUSSY MONEY FAME',
#  'U Sellin Dope (with Future)',
#  'Motorcycle Patches',
#  'Stayback',
#  'Just A Memory - Mild Minds Remix',
#  "Llamé Pa' Verte (Bailando Sexy)",
#  'Días y Meses',
#  'Afeitate',
#  'Definitivamente',
#  'Krazy but True',
#  '90210 (feat. Kacy Hill)',
#  'Loco Por Perrearte - Remix',
#  'City of Gods (Part II)',
#  'Bounce Out With That Remix (feat. Machine Gun Kelly)',
#  'Intro',
#  'Go Crazy',
#  'Juice (feat. YG)',
#  'Before I Die',
#  'Mess',
#  "Can't Feel My Face",
#  'Mi Vicio',
#  'Often',
#  'Bird Shit',
#  'Necio (feat. Carlos Santana)',
#  'Pero Ya No',
#  'Like This',
#  'Feel The Love',
#  'Grinding All Season',
#  'Coaster',
#  'Own It',
#  'La Pega Cuernos',
#  'Bonita',
#  'Lodi Dodi',
#  'Free Porn Cheap Drugs',
#  'No Guidance (feat. Drake)',
#  'Practice',
#  'P FKN R',
#  'Rambo',
#  'too far close',
#  'Been That Way',
#  "DON'T WORRY (feat. Ca$h Out)",
#  'The Adventures of Moon Man & Slim Shady (with Eminem)',
#  'Solteroski',
#  'In The Dark',
#  'Voodoo (with J Balvin & Tainy)',
#  'If You Let Me',
#  'Paramedic!',
#  '"BOP"',
#  'Do It Right',
#  'KMT',
#  'Obsesion (No Es Amor) (feat. Mr. Phillips) - Luny Tunes Reggaeton Remix',
#  'Malportau',
#  'Perreo y Dembow',
#  '6 God',
#  'Tomorrow 2 (with Cardi B)',
#  'PICK IT UP (feat. A$AP Rocky)',
#  'Neverita',
#  'Corn Maze',
#  'Get Fly (feat. DaBaby)',
#  'After The Storm (feat. Tyler, The Creator & Bootsy Collins)',
#  'The Birds Pt. 2',
#  'Topanga',
#  'Stars Align (with Drake)',
#  'HACIENDO QUE ME AMAS',
#  '1942 (feat. Yo Gotti & YBN Nahmir)',
#  'Chaos',
#  'Tap Out II - Open Verse',
#  'Amantes y Amigos',
#  'RLNDT',
#  'Wants and Needs (feat. Lil Baby)',
#  'Do Not Disturb',
#  'Finesse',
#  '0 To 100 / The Catch Up',
#  'LENTITO',
#  'ME VOY | E9',
#  'Rude',
#  'ANTES QUE SE ACABE',
#  'OSOM (feat. J. Cole)',
#  'Vivir Bailando',
#  'PARA SIEMPRE',
#  'Recuerdos',
#  'Billete Grande (En Vivo)',
#  'Tonika (feat. Ziggy Marley)',
#  'In and Out',
#  'Chains',
#  'Grapes Alla Vodka - Salva Remix',
#  "Puesto Pa' Ti (feat. Farina)",
#  "Don't Come Out The House (with 21 Savage)",
#  'White Tee (with NO1-NOAH)',
#  'Plain Jane REMIX (feat. Nicki Minaj)',
#  "I Can't Save You (Interlude) [with Future & feat. Don Toliver]",
#  'SI SUPIERAS',
#  'El Respaldo',
#  'None To Me',
#  'No Long Talk',
#  'Jaigantic (Galimatias Remix)',
#  'You Never Know',
#  'Shordie (with Gunna)',
#  'Contra la Corriente',
#  'Worst Behavior',
#  'Fruit Salad',
#  'Bleed It',
#  'Light Switch',
#  'N 2 Deep',
#  'GUMMY',
#  'El Manual',
#  'Feds',
#  'HELLCAT',
#  'Top Off',
#  'Uber Wit A Dub (feat. Lul G, DaBoii & Yhung T.O.)',
#  'Clap - From Road To Fast 9 Mixtape',
#  'Pink Matter',
#  'Jele',
#  'Quality',
#  'Dark Hearted',
#  'Imperial',
#  'sdp interlude',
#  'Tonteria',
#  'Small Talk',
#  'Peloton',
#  'Phone Jumpin',
#  'Despues Del Choli',
#  'White Tee (with NO1-NOAH)',
#  'Wannabe',
#  '2',
#  'Slide',
#  "Who's Stopping Me (& Metro Boomin)",
#  'Undo (Back To My Heart)',
#  'Bad Habits',
#  'Run It Up (feat. Pop Smoke)',
#  'Pauta & Flow',
#  'Soul Searching',
#  'OLD DAYS',
#  'Pure Water (with Migos)',
#  '9',
#  'Nothing Compares - Bonus Track',
#  'Me Fui de Vacaciones',
#  'Lies (feat. Ty Dolla $ign & YG)',
#  'Foot Fungus',
#  'Pantera',
#  'Shot For Me',
#  'Somo o No Somos',
#  'Scotty Pippen',
#  "I'm Ready For You",
#  'Beautiful',
#  'La Corriente',
#  'YO LE LLEGO',
#  "U Don't Have to Call",
#  'Puerto Rico',
#  'Rakataka',
#  'Privilege',
#  'Liability',
#  'Foolish',
#  'On Guard (feat. 6lack)',
#  'Playa Hater',
#  'High For This',
#  'Lost Me (with RealestK)',
#  'Time Piece (feat. Lil Durk)',
#  'Kevin’s Heart',
#  'Lock On Me (with Travis Scott & Future)',
#  'Los Dioses',
#  'Mr. Morale',
#  'AIGHT (feat. Shelley FKA DRAM)',
#  'Lleca',
#  'Señor Miedo',
#  'Soy Peor - Remix',
#  'Poblado - Remix',
#  'Out for the Night - Live',
#  'Bring You Down',
#  'Captain Crunch (feat. Babyface Ray, Sada Baby, & Icewear Vezzo)',
#  'Tell Me U Luv Me (with Trippie Redd)',
#  'Mood (feat. Zacari)',
#  '5% TINT',
#  'Chasing Marrakech',
#  'Handsome And Wealthy',
#  'Blanco',
#  'Replace Me (feat. Big Sean & Don Toliver)',
#  'Yonaguni',
#  'Malos Ratos',
#  'Top Down On Da NAWF',
#  'Innocence (feat AlunaGeorge)',
#  'These Walls',
#  'Motivation',
#  'See You Again (feat. Kali Uchis)',
#  'None To Me',
#  'Bella-K (feat. Zion & Randy)',
#  "I'm Ready For You",
#  'Smile (with The Weeknd)',
#  '28',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Efecto',
#  'Lleca',
#  'Politics',
#  'History',
#  'HOUSTONFORNICATION',
#  'Gore',
#  'Tarot',
#  'blood on the leaves',
#  'Wu-Tang Forever',
#  'Life Letters',
#  '100',
#  'Lithuania (feat. Travis Scott)',
#  'slop',
#  'Blastoff (feat. Juice Wrld & Trippie Redd)',
#  'Sin Filtro',
#  'FEEL.',
#  'Atrapado en un Sueño',
#  'Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)',
#  'Darte Remix',
#  'Held Me Down',
#  'Over The Top (feat. Drake)',
#  'Ski Mask',
#  '28 Gramos',
#  'Ghetto Star',
#  'Te Robaré',
#  '23',
#  'Super Mario World',
#  'Planet Rock',
#  'Not the Same',
#  'Condones',
#  'One, Two Step (feat. Missy Elliott)',
#  'Big Shot (with Travis Scott)',
#  'beibs in the trap',
#  'Por Mi Reggae Muero 2020',
#  'ball w/o you',
#  'Watch (feat. Lil Uzi Vert & Kanye West)',
#  'Lovers Anonymous',
#  'La Maria',
#  'POCKET ROCKET',
#  'Same Girl (with Usher)',
#  'FWM',
#  '¿Cual Es Tu Plan?',
#  'Too Many Problems',
#  'Water (feat. Lil Baby)',
#  'Hot Hands',
#  'Tu Lo Sabes',
#  'PARA SIEMPRE',
#  'Ms. New Booty',
#  'Euphoria (feat. Travis Scott & Kaash Paige)',
#  'Teenage Fever',
#  'It Was A Good Day',
#  'fue mejor (feat. SZA)',
#  '23 Preguntas',
#  'Heaven Or Hell',
#  'Te Boté - Remix',
#  'Mo Bamba',
#  'Start This Shit Off Right (feat. Ashanti & Mack Maine)',
#  'YO LE LLEGO',
#  'I Keep Calling',
#  'Dedicate',
#  '1134',
#  'La Negra Tomasa - Tema Remasterizado',
#  'The Motion',
#  'How You Feel',
#  'fue mejor (feat. SZA)',
#  '6 Man',
#  'Rumba',
#  'Vida Buena',
#  'Out The Mud',
#  'Even Steven',
#  'Numb Numb Juice',
#  'I Hate U',
#  'Harleys In Hawaii',
#  'Ay Caramba',
#  'Ugotme',
#  'In and Out',
#  'Need to Know',
#  'Feeling Good Today',
#  'Shea Butter Baby (with J. Cole)',
#  'All Me',
#  'A-Team',
#  'Not You Too (feat. Chris Brown)',
#  'Super Rich Kids',
#  'In For It',
#  'Extasy',
#  'Malos Ratos',
#  'Hi This Is Flume',
#  'EL HOMBRE PERFECTO',
#  'Como Llora',
#  'HIDEOUT (feat. Fijimacintosh)',
#  'Special Remix (feat. Moneybagg Yo)',
#  'No Complaints',
#  'Hoodie',
#  'changes',
#  'Babystar',
#  'Dior',
#  'Powerglide (feat. Juicy J) - From SR3MM',
#  'Estrés Postraumático',
#  'BILLY',
#  'Rose Golden',
#  'Hype',
#  'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) - Remix',
#  'Hay Que Hacer Dinero',
#  'A Day Without a Mexican',
#  'Papi’s Home',
#  'Stay Awake',
#  'Privileged Rappers',
#  'Enjoy Yourself (feat. Karol G)',
#  'Killing Me Softly With His Song',
#  'too far close',
#  'No More (feat. Travis Scott, Kodak Black & 21 Savage)',
#  'too far close',
#  'The Weekend - Funk Wav Remix',
#  'Habit - Blood Cultures Remix',
#  'GIVENCHY',
#  'Desnudarte',
#  'Preparado',
#  'Abajo y Arriba (with Juhn)',
#  'Know Me',
#  '7 Min Freestyle',
#  'Wassup',
#  'Pelo Alborotau',
#  'Los Rompediskoteca',
#  'Dark Knight Dummo (Feat. Travis Scott)',
#  'Buttered Up',
#  'Impossible',
#  'New Feeling',
#  'Projects',
#  'Faith (feat. Quavo)',
#  'Honest (feat. Don Toliver)',
#  'Punto y Aparte',
#  'Satisfacción',
#  'Still Here',
#  'P2',
#  'durag activity (with Travis Scott)',
#  'RD',
#  'Leray',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Thinkin (feat. Anuel AA, Bad Bunny & Future)',
#  'Tap (feat. Meek Mill)',
#  'Go Loko',
#  'MODO DEPRE :(',
#  'After Hours',
#  'Que Es Esto?',
#  'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)',
#  'What You Need - Original',
#  'Sno Cone (feat. Quavo & Gucci Mane)',
#  'Experimento 01',
#  'Obsesion (No Es Amor) (feat. Baby Bash)',
#  'Free Porn Cheap Drugs',
#  'Hardest To Love',
#  'Acting Like',
#  'Love... (Her Fault) [feat. Bryson Tiller]',
#  'Bubalu',
#  'When I Talk',
#  'Insane',
#  'Closed On Sunday',
#  'Marinero',
#  'Stupid Me',
#  'Culo Chapa (feat. La Perversa, Quimico Ultra Mega & Haraca Kiko)',
#  'Sitting In The Corner (feat. Adriel Favela & Kacey Musgraves)',
#  'Sukutubla',
#  'Enjoy Yourself (feat. Karol G)',
#  "Can't Have Everything",
#  'Dispuesto (feat. Ozuna)',
#  'Ice Melts',
#  'A Solas (House)',
#  'NC-17',
#  'La Corriente',
#  'Mi Favorita',
#  'Scotty Pippen',
#  'Nothings Into Somethings',
#  "Bria's Interlude (feat. Omarion)",
#  'I Like That',
#  'Ecdysis',
#  "Don't Rush - Remix",
#  'Te Boté II',
#  'Enseñame',
#  "King's Dead (with Kendrick Lamar, Future & James Blake)",
#  'Alone Again',
#  'After Party',
#  'Dictadura',
#  "It's Officially Done",
#  'Drug Dealer',
#  'COMO UN BEBÉ',
#  'Never Know',
#  'Bendición Mami',
#  'KANGA',
#  'Hella Fun (feat. Jay Anthony)',
#  'VIDA LOCA',
#  'Famous',
#  'Mile High (feat. Travis Scott & Metro Boomin)',
#  'Ring (feat. Young Thug)',
#  '"BOP"',
#  'En La Disco Revela',
#  'Faneto',
#  "King's Dead (with Kendrick Lamar, Future & James Blake)",
#  'Limoncello',
#  "Put Me on Somethin'",
#  'Audi.',
#  'Z4L (with Bari & Jay2)',
#  'Gore',
#  'Fuck It up (feat. Yg)',
#  'Feel The Love',
#  'Inmortal',
#  'BIZCOCHITO',
#  'Falling For You',
#  'Said Sum (feat. City Girls & DaBaby) - Remix',
#  'Safari',
#  'Shut up My Moms Calling',
#  'Tetris',
#  'Keep Calling',
#  'L.N.E.M. (GATA) (feat. Kapla y Miky, Philip Ariaz & Blessd)',
#  'On Top (feat. T.Shirt)',
#  'The Birds Pt. 1',
#  'Me Gusta Tanto',
#  'De Lao A Lao: Turreo Sessions #5 - Remix',
#  'Chupable',
#  'Splashin',
#  'Tarot',
#  'Drop the Game',
#  'How You Feel',
#  'Monte Carlo (feat. WET)',
#  'You Never Know',
#  'Desnudarte',
#  'Lucky You (feat. Joyner Lucas)',
#  'Porsches In The Rain',
#  'If You Let Me',
#  '11 PM',
#  'Still',
#  'El JP',
#  'Baila Conmigo (feat. Kelly Ruiz)',
#  'Fighting Demons',
#  'Si Se Da - Remix',
#  'Donde Quieres',
#  'la luz(Fín)',
#  'Bonjour (feat. Summer Walker)',
#  'Un Beso',
#  'De Lao A Lao: Turreo Sessions #5 - Remix',
#  'Ball in Peace (Outro)',
#  'Views',
#  'THat Part - Black Hippy Remix',
#  'Lemonade',
#  'Leave The Door Open',
#  '3AM (From "Animal Crossing: Wild World") [Cover]',
#  '42.26',
#  'Duvibes',
#  'Cuántas veces',
#  'Te Extraño',
#  'Vivir Bailando',
#  'El JP',
#  'Romeo & Juliet',
#  'NO RAP KAP (feat. Trippie Redd)',
#  'Places',
#  'Nuevo',
#  'Por Mi Reggae Muero 2020',
#  'Drink To This',
#  'Wicked Freestyle',
#  'BELIEVE (feat. Don Toliver)',
#  'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) - Remix',
#  'Instagram',
#  'EYE ON IT',
#  'High Beams',
#  'Invincible',
#  "Megan's Piano",
#  'Wow.',
#  'Decadent',
#  'Black Privilege',
#  'Faithful',
#  'Controlla',
#  'La Difícil',
#  'Hawái',
#  'Paris to Tokyo',
#  'Undo (Back To My Heart)',
#  'UN PESO',
#  'What You Need',
#  'Girls Need Love',
#  'Hasta Que Dios Diga',
#  'Woah Woah Woah',
#  'Miss The Rage (feat. Playboi Carti)',
#  'Kill Them All',
#  'Come Thru',
#  'Me Olvidare de Ti',
#  'No Idea',
#  'GEEKALEEK (feat. Cash Kidd)',
#  'Party Favors (feat. Young Thug)',
#  'Powerglide (feat. Juicy J)',
#  'Ezra',
#  'Wraith',
#  'Estás en Mí Pasado',
#  'Hit This Hard',
#  'Take a Chance (feat Little Dragon)',
#  'Easy (feat. 6LACK)',
#  'cocoa (with Don Toliver)',
#  '19',
#  'How Bout Now',
#  'Señor Miedo',
#  'Jump Out the Face (feat. Future)',
#  'For The Night (feat. Lil Baby & DaBaby)',
#  'HOW BOUT THAT?',
#  'Legacy (feat. Travis Scott & 21 Savage)',
#  'Get Money (feat. Junior M.A.F.I.A.) - 2007 Remaster',
#  'Juice (feat. YG)',
#  'Sticky',
#  'Amor Tirano',
#  'Mood (feat. Zacari)',
#  'U Sellin Dope (with Future)',
#  'SWM',
#  'NO MIENTEN',
#  'KICK (feat. 6ix9ine)',
#  'I Dance (feat. Duki & Cuco)',
#  'We Rising',
#  'House Key',
#  'Swipe Life (feat. Rick Ross)',
#  'X Ley (feat. Dei V) - Remix',
#  'Sigues Con El - Remix',
#  'TE MUDASTE',
#  'Bandoleros',
#  'SUSANA (Remix)',
#  'Shake The Room (feat. Quavo)',
#  'STOP TRYING TO BE GOD',
#  'Can’t Take A Joke',
#  'West Coast',
#  'Beast',
#  "Neu Roses (Transgressor's Song)",
#  'Duvibes',
#  'Chamber Of Reflection',
#  'Para Todos Mis Paisanos',
#  'Still',
#  'Chucky Cheese',
#  'Joro',
#  'DAMN HOMIE (feat. Lil Yachty)',
#  'WAKE UP',
#  'Is There Someone Else?',
#  'E-ER (feat. Lil Yachty)',
#  'Lamento Boliviano',
#  "I Can't Tell (feat. LAUREL)",
#  'Holdin On - Hermitude Remix',
#  'All Facts Not 1 Opinion (feat. Slimmy B & DaBoii)',
#  'Que Rica (Tocame)',
#  'Focus (feat. 21 Savage)',
#  'Monte Carlo (feat. WET)',
#  'El Perdedor',
#  'Futsal Shuffle 2020',
#  'Time Flies',
#  '90mh',
#  'Peloton',
#  'Thursday',
#  'you & me',
#  'El Velador',
#  'Mentiras',
#  'Bésame',
#  'Light Switch',
#  'The Birds Pt. 1',
#  'Familia (with Anuel Aa, feat. Bantu) - Spider-Man: Into the Spider-Verse',
#  'Some Minds (feat. Andrew Wyatt)',
#  'Sexo Sin Titulo (feat. Jay Wheeler & Lenny Tavárez)',
#  'Dark Hearted',
#  'Places',
#  'La Safaera (Megamix)',
#  'Pound Cake / Paris Morton Music 2',
#  'Marinero',
#  'INVENTED IT',
#  'Too Good',
#  'Dembow 2020',
#  'Saint',
#  'Supastars',
#  'Grapes Alla Vodka - Salva Remix',
#  'Lies (feat. Ty Dolla $ign & YG)',
#  'Dos Mil 16',
#  'Places',
#  'Todo Bien',
#  'Hedonismo',
#  'Love & Drugz II',
#  'See You Again (feat. Kali Uchis)',
#  '...And To Those I Love, Thanks For Sticking Around',
#  'ALL I NEED (feat. Drake)',
#  'Summers Over Interlude',
#  'SAL DE MI CABEZA',
#  'Aullando',
#  'Acting Like',
#  'Everybody Dies In Their Nightmares',
#  'Mood',
#  'Nibiru',
#  'Essence (feat. Justin Bieber & Tems)',
#  'El Telefono',
#  'Luv Drunk',
#  'Free (Outro)',
#  'Icon',
#  'ZEZE (feat. Travis Scott & Offset)',
#  'Beautiful',
#  'LENTITO',
#  '712PM',
#  'Might as Well',
#  'Guatauba',
#  'Squidwards Nose (feat. Kg Prince)',
#  'Sunbathe',
#  'Un Coco',
#  "I'm Ready For You",
#  'Zoo York (feat. Fivio Foreign & Pop Smoke)',
#  'Solita',
#  'Ella Me Levanto',
#  'Para Todos Mis Paisanos',
#  'RLNDT',
#  'Water (feat. Lil Baby)',
#  'Casper',
#  'Oye Mujer',
#  'El Deportivo',
#  'Do It To It',
#  'Subimos de Rango',
#  'HOTEL LOBBY (Unc & Phew)',
#  'My Love (feat. T.I.)',
#  'We Rising',
#  'BUBBLE GUM',
#  '"BOP"',
#  'Exchange',
#  'TR666',
#  'Champagne Shots',
#  'N95',
#  'Vibe',
#  'Delincuente',
#  '2 Vaults (feat. Lil Yachty)',
#  'Rest in Peace',
#  'She Miss Me (feat. Rich the Kid)',
#  "LET'S PRAY (feat. Don Toliver & Travis Scott)",
#  'What’s New',
#  'Over',
#  'Like Water (feat. MNDR)',
#  'West Coast',
#  'Virtual Fish Market',
#  'All Me',
#  'Rakataka',
#  'BULLETPROOF (feat. Jay 305)',
#  'Amorfoda',
#  'Let It All Work Out',
#  "Flight's Booked",
#  'Tie That Binds',
#  'Cardigan',
#  'PRBLMS',
#  'RLNDT',
#  'Somo Así',
#  'Química (feat. The Martinez Brothers)',
#  'Feliz de Mentira',
#  'Amor Tirano',
#  'A Mi Si Me Gusta',
#  'Flex Up (feat. Future & Playboi Carti)',
#  'SLOW DANCING IN THE DARK',
#  'Rasta Barbie (Remix)',
#  'Jaigantic (Galimatias Remix)',
#  'Lose You',
#  'IMY2 (with Kid Cudi)',
#  'No Guidance (feat. Drake)',
#  'Súbelo',
#  'Scotty Pippen',
#  'Even Steven',
#  'Betrayal (feat. Drake)',
#  'La 2blea',
#  "Can't Get Enough",
#  'Understand',
#  'Lay Me Down - Flume Remix',
#  'Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#  'Ugotme',
#  'Fruit Salad',
#  'QUE PRETENDES',
#  'Always Forever',
#  'His & Hers (feat. Don Toliver, Lil Uzi Vert & Gunna)',
#  'MOOO!',
#  'Whip (feat. Travis Scott)',
#  'Como Antes',
#  'Top 5 (feat. Playboi Carti)',
#  'Love & Drugz II',
#  '100 Años',
#  'Levels',
#  'Psycho',
#  'Get It Together',
#  'Circo Loco',
#  'Saucy',
#  'Ki (feat. Daniel Habif)',
#  'Diplomatic Immunity',
#  'Santal 33',
#  'I Am',
#  "Stunting Ain't Nuthin (feat. Slim Jxmmi & Young Dolph)",
#  'T-Shirt',
#  'Playing Games (with Bryson Tiller) - Extended Version',
#  'THE NEWS',
#  'The Mantra - From "Creed II: The Album"',
#  'Miss me',
#  'Faucet Failure',
#  'Ezra',
#  'BLOOD.',
#  'The Big Unknown (From "Widows")',
#  'Vixen',
#  'Big Boy Diamonds (feat. Kodak Black & London on Da Track)',
#  'Jill (Sumn Real)',
#  'Stay Schemin',
#  'Water (Drowning Pt. 2) [feat. Kodak Black]',
#  'Nadie Como Tú',
#  'Last Forever (feat. Rick Ross & Snoop Dogg)',
#  'Why You Crying Mama',
#  'Sky Walker (feat. Travis Scott)',
#  'Feds',
#  'Tu Vecina (feat. Ty Dolla $ign)',
#  'Plan A',
#  'Vibe',
#  'Me Olvidare de Ti',
#  'Dos Uno Nueve (219)',
#  'Con La Brisa',
#  'Vanish',
#  'Tequila Shots',
#  'blood on the leaves',
#  'Te Ire A Buscar',
#  'Feel',
#  'So Good (& Metro Boomin)',
#  'Nasty',
#  'Black & Chinese',
#  'Te Boté II',
#  'Anti',
#  'La Única - Sprite Limelight',
#  "I'm Not The Only One",
#  'Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#  'Bonita',
#  'Fly',
#  'Undo (Back To My Heart)',
#  'Don',
#  'Tumbados En Miami',
#  'AL CAPONE',
#  'You Better Move',
#  'On BS',
#  'Like a Tattoo',
#  'Soy El Diablo - Remix',
#  'La Mamá de la Mamá',
#  'Stupid Me',
#  'WORKIN ME',
#  'Mi Favorita',
#  'Nonstop',
#  'Escápate Conmigo',
#  "Pa' Que La Pases Bien",
#  'Lift Me Up - From Black Panther: Wakanda Forever - Music From and Inspired By',
#  'PUSSY MONEY FAME',
#  'Nasty',
#  'Stan By Me',
#  'Luv (sic)',
#  'MOOO!',
#  'Qué Chimba',
#  'Hold Your Breath (feat. Gunna)',
#  'Whole Brick',
#  'Selah',
#  'untitled 07 | 2014 - 2016',
#  'Nothing Compares - Bonus Track',
#  'Holy Grail',
#  'Breath Control (feat. Wiz Khalifa)',
#  'Felices los 4',
#  'Superman',
#  'Quickie',
#  "Since '84",
#  'I WANNA SEE SOME ASS (feat. jetsonmade)',
#  'Lies (feat. Ty Dolla $ign & YG)',
#  'Lo Se',
#  'Amor Tirano',
#  'Love & Loyalty (Believe)',
#  'Deep End Freestyle',
#  'Floating (feat. 21 Savage)',
#  'All Girls Are The Same',
#  'Until I Bleed Out',
#  'Safeguard',
#  'Miss Me',
#  'Seek & Destroy',
#  'Hold Your Breath (feat. Gunna)',
#  'Sleepy Hollow',
#  'changes',
#  'The Adventures Of Stoney Bob (ft. Kajo, Slaydro, Big Lenbo)',
#  'De La Calle (Remix)',
#  'Coaster',
#  'One Up',
#  'Medusa',
#  'Smile (with The Weeknd)',
#  'Leray',
#  'Overtime (feat. Sebastian Reynoso & KYLE)',
#  'Champion (feat. Travis Scott)',
#  'GOD.',
#  'Piensas en Mí',
#  'No Te Creo',
#  'See Me (Step Up: Season 3, Original Soundtrack)',
#  'Something Foreign',
#  'Dimelo',
#  'High Highs to Low Lows',
#  'Nasty',
#  'Señor Miedo',
#  'BUBBLE GUM',
#  'Bounce Out With That Remix (feat. Machine Gun Kelly)',
#  'you & me',
#  'Top Off',
#  'Die For You',
#  '3am',
#  'YOSEMITE',
#  'Casper',
#  'Where U From',
#  'Busca un Culo',
#  "Don't Let Me Down (feat. Khalid)",
#  'Paper Planes',
#  'La H',
#  'Keraunos',
#  '4422',
#  'Holdin On - Hermitude Remix',
#  'Staccato',
#  'Black Panther',
#  'Griztronics',
#  'Mi Vicio',
#  'Excitement',
#  'Bagre',
#  'Chendo',
#  'Mood',
#  'Quickie',
#  'HIGHEST IN THE ROOM',
#  "Don't Miss It",
#  'Soul Searching',
#  'Chall Ready Know',
#  'Need to Know',
#  'LOSE IT (feat. Lil Baby)',
#  '44 Bars',
#  'Señor Miedo',
#  'JAPAN',
#  '3',
#  'Twilight City',
#  'La Jumpa',
#  'Have A Nice Day',
#  'Babystar',
#  'Flea Market',
#  'ULTRA VIOLET',
#  'Blastoff (feat. Juice Wrld & Trippie Redd)',
#  'No Less',
#  'I Keep Calling',
#  'Ay, DiOs Mío!',
#  'No Digas Mi Nombre',
#  'Drugz',
#  'Desnudarte',
#  'I Remember',
#  "What's Up (feat. Jagged Edge)",
#  'Final Fantasy',
#  'You',
#  'Love Me',
#  'Christopher Walking',
#  ...]

# %%
# showing list of songs 
shuffled_playlist
# Out:
# ['Bien Arrebatao',
#  'CHARLIE',
#  'Yo x Ti, Tu x Mi',
#  'L.N.E.M. (GATA) (feat. Kapla y Miky, Philip Ariaz & Blessd)',
#  'Traicionera',
#  'Childs Play',
#  'Prices',
#  "Why DON'T You LOVE me?",
#  'Brisa',
#  'Blue Tint',
#  'Pikete',
#  'GOD.',
#  'Don’t Break My Heart',
#  'Perriando',
#  'If I Ruled the World (Imagine That) (feat. Lauryn Hill)',
#  'Santorini',
#  'Better Things',
#  'Hype',
#  'Después de la Playa',
#  'No Es Normal',
#  '25/8',
#  'WHATS POPPIN',
#  'What’s New',
#  'Feds',
#  'Buckets (feat. Future) - From SR3MM',
#  'Lovers Anonymous',
#  'A La Perfección',
#  'Flow HP',
#  'Inmortal',
#  'Free',
#  'Ansiedad',
#  'SORRY PAPI',
#  '1 Thot 2 Thot Red Thot Blue Thot',
#  'Safaera',
#  'Pose (feat. Lil Uzi Vert)',
#  'Pass It (feat. G-Eazy)',
#  'Perreo Intenso',
#  'Survival',
#  'Un Polvo (feat. Bad Bunny, Arcángel, Ñengo Flow & De La Ghetto)',
#  'Eres Mía',
#  'La Forma en Que Me Miras',
#  'Cucumber Water',
#  'Baby',
#  'honey baby (SPOILED!)',
#  'DeLorean',
#  'Everybody',
#  'Un Ratito',
#  'On BS',
#  'No Complaints',
#  'Dimelo',
#  'Killing Me Softly With His Song',
#  'Heavy (with Lil Uzi Vert)',
#  'Got Friends',
#  'Celebrate (feat. Travis Scott & Post Malone)',
#  'True Love',
#  "No Tellin'",
#  'Thank You (ft. Lucy Rose & The RattPack)',
#  'PRIDE.',
#  'CAROUSEL',
#  'Splashin',
#  'Si te Vas - The Remix',
#  'Tumbados En Miami',
#  'Focus (feat. 21 Savage)',
#  'Lo Que Necesitas',
#  "Llamé Pa' Verte (Bailando Sexy)",
#  "Pa' Que La Pases Bien",
#  'Vete',
#  'Before I Die',
#  'Still',
#  'Take Me Away (From Freaky Friday)',
#  'ESTILAZO',
#  'Sólo Amigos',
#  'She For Keeps',
#  '3',
#  'Calling My Spirit',
#  'Beautiful',
#  'Back To Sleep',
#  'Dale',
#  'Culture National Anthem - Outro',
#  'Randy Johnson',
#  'Sweet Thangs',
#  'Mercedes',
#  'Gave Your Love Away',
#  'GREECE (feat. Drake)',
#  'Atrapado en un Sueño',
#  'Wrong Decisions',
#  'Dime Tu',
#  'DadBod',
#  'First Off (feat. Travis Scott)',
#  "Can't Get Enough",
#  'In Da Getto',
#  'GOOBA',
#  'Outside Today',
#  'Después de la Playa',
#  'GUMMO',
#  'Couch',
#  'Out of Time',
#  'GRACIAS POR NADA',
#  'Muévelo Lento',
#  'GRACIAS POR NADA',
#  'El Respaldo',
#  'Like a Tattoo',
#  'BOOKER T',
#  'HUMBLE.',
#  'Race My Mind',
#  'Un Verano Sin Ti',
#  "Oodles O' Noodles Babies",
#  'DARK BROTHERHOOD (feat. Lil Baby)',
#  'Essence (feat. Justin Bieber & Tems)',
#  'Taking Chances',
#  'NO MÁS (feat. Quavo, J. Balvin, Anitta, and Pharrell)',
#  'What You Know',
#  'La Cama - Remix',
#  'Trust Issues',
#  '18 Months (feat. Ty Dolla $ign)',
#  'Champagne Shots',
#  'Ya Digg',
#  'PANTIES Y BRASIERES',
#  'Nights',
#  'Blow',
#  'Kill Them All',
#  'NO SNITCHING (with Dusty Locane)',
#  'Miss Independent',
#  'Keep Calling',
#  'Be Your Girl (Kaytranada Edition)',
#  'PASS OUT (feat. 21 Savage)',
#  'Saint Laurent Mask',
#  'Pussy & Millions (feat. Travis Scott)',
#  'Bonita',
#  'Feel',
#  'STOP TRYING TO BE GOD',
#  'Fantastic',
#  'The Tip Out',
#  'Fin',
#  'PICK IT UP (feat. A$AP Rocky)',
#  'Diamantes en Mis Dientes',
#  'Vitality',
#  'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)',
#  'Overnight',
#  'SORRY PAPI',
#  'EARFQUAKE',
#  'Zendaya (feat. J. Cole)',
#  'Bring You Down',
#  "Can't Have Everything",
#  'Last Call',
#  'Sold Out Dates (feat. Lil Baby)',
#  'Sexo Sin Titulo (feat. Jay Wheeler & Lenny Tavárez)',
#  'Mentiras',
#  'Take Me Away',
#  'LOYALTY. FEAT. RIHANNA.',
#  'Perfect',
#  'Iridescent',
#  'The Motion',
#  'Betrayal (feat. Drake)',
#  "Everybody's Gotta Learn Sometime",
#  'Winnie Pooh',
#  'Holdin On',
#  'Rick & Morty',
#  'Taking A Walk',
#  "Where's The Catch? (feat. André 3000)",
#  'Snow White',
#  'Feeling Myself Today',
#  'Sign of the Times',
#  'Brag (feat. Fivio Foreign)',
#  'Eye 2 Eye',
#  'Said Sum (feat. City Girls & DaBaby) - Remix',
#  'Faith (feat. Quavo)',
#  'Como Antes',
#  'PUSSY MONEY FAME',
#  'U Sellin Dope (with Future)',
#  'Motorcycle Patches',
#  'Stayback',
#  'Just A Memory - Mild Minds Remix',
#  "Llamé Pa' Verte (Bailando Sexy)",
#  'Días y Meses',
#  'Afeitate',
#  'Definitivamente',
#  'Krazy but True',
#  '90210 (feat. Kacy Hill)',
#  'Loco Por Perrearte - Remix',
#  'City of Gods (Part II)',
#  'Bounce Out With That Remix (feat. Machine Gun Kelly)',
#  'Intro',
#  'Go Crazy',
#  'Juice (feat. YG)',
#  'Before I Die',
#  'Mess',
#  "Can't Feel My Face",
#  'Mi Vicio',
#  'Often',
#  'Bird Shit',
#  'Necio (feat. Carlos Santana)',
#  'Pero Ya No',
#  'Like This',
#  'Feel The Love',
#  'Grinding All Season',
#  'Coaster',
#  'Own It',
#  'La Pega Cuernos',
#  'Bonita',
#  'Lodi Dodi',
#  'Free Porn Cheap Drugs',
#  'No Guidance (feat. Drake)',
#  'Practice',
#  'P FKN R',
#  'Rambo',
#  'too far close',
#  'Been That Way',
#  "DON'T WORRY (feat. Ca$h Out)",
#  'The Adventures of Moon Man & Slim Shady (with Eminem)',
#  'Solteroski',
#  'In The Dark',
#  'Voodoo (with J Balvin & Tainy)',
#  'If You Let Me',
#  'Paramedic!',
#  '"BOP"',
#  'Do It Right',
#  'KMT',
#  'Obsesion (No Es Amor) (feat. Mr. Phillips) - Luny Tunes Reggaeton Remix',
#  'Malportau',
#  'Perreo y Dembow',
#  '6 God',
#  'Tomorrow 2 (with Cardi B)',
#  'PICK IT UP (feat. A$AP Rocky)',
#  'Neverita',
#  'Corn Maze',
#  'Get Fly (feat. DaBaby)',
#  'After The Storm (feat. Tyler, The Creator & Bootsy Collins)',
#  'The Birds Pt. 2',
#  'Topanga',
#  'Stars Align (with Drake)',
#  'HACIENDO QUE ME AMAS',
#  '1942 (feat. Yo Gotti & YBN Nahmir)',
#  'Chaos',
#  'Tap Out II - Open Verse',
#  'Amantes y Amigos',
#  'RLNDT',
#  'Wants and Needs (feat. Lil Baby)',
#  'Do Not Disturb',
#  'Finesse',
#  '0 To 100 / The Catch Up',
#  'LENTITO',
#  'ME VOY | E9',
#  'Rude',
#  'ANTES QUE SE ACABE',
#  'OSOM (feat. J. Cole)',
#  'Vivir Bailando',
#  'PARA SIEMPRE',
#  'Recuerdos',
#  'Billete Grande (En Vivo)',
#  'Tonika (feat. Ziggy Marley)',
#  'In and Out',
#  'Chains',
#  'Grapes Alla Vodka - Salva Remix',
#  "Puesto Pa' Ti (feat. Farina)",
#  "Don't Come Out The House (with 21 Savage)",
#  'White Tee (with NO1-NOAH)',
#  'Plain Jane REMIX (feat. Nicki Minaj)',
#  "I Can't Save You (Interlude) [with Future & feat. Don Toliver]",
#  'SI SUPIERAS',
#  'El Respaldo',
#  'None To Me',
#  'No Long Talk',
#  'Jaigantic (Galimatias Remix)',
#  'You Never Know',
#  'Shordie (with Gunna)',
#  'Contra la Corriente',
#  'Worst Behavior',
#  'Fruit Salad',
#  'Bleed It',
#  'Light Switch',
#  'N 2 Deep',
#  'GUMMY',
#  'El Manual',
#  'Feds',
#  'HELLCAT',
#  'Top Off',
#  'Uber Wit A Dub (feat. Lul G, DaBoii & Yhung T.O.)',
#  'Clap - From Road To Fast 9 Mixtape',
#  'Pink Matter',
#  'Jele',
#  'Quality',
#  'Dark Hearted',
#  'Imperial',
#  'sdp interlude',
#  'Tonteria',
#  'Small Talk',
#  'Peloton',
#  'Phone Jumpin',
#  'Despues Del Choli',
#  'White Tee (with NO1-NOAH)',
#  'Wannabe',
#  '2',
#  'Slide',
#  "Who's Stopping Me (& Metro Boomin)",
#  'Undo (Back To My Heart)',
#  'Bad Habits',
#  'Run It Up (feat. Pop Smoke)',
#  'Pauta & Flow',
#  'Soul Searching',
#  'OLD DAYS',
#  'Pure Water (with Migos)',
#  '9',
#  'Nothing Compares - Bonus Track',
#  'Me Fui de Vacaciones',
#  'Lies (feat. Ty Dolla $ign & YG)',
#  'Foot Fungus',
#  'Pantera',
#  'Shot For Me',
#  'Somo o No Somos',
#  'Scotty Pippen',
#  "I'm Ready For You",
#  'Beautiful',
#  'La Corriente',
#  'YO LE LLEGO',
#  "U Don't Have to Call",
#  'Puerto Rico',
#  'Rakataka',
#  'Privilege',
#  'Liability',
#  'Foolish',
#  'On Guard (feat. 6lack)',
#  'Playa Hater',
#  'High For This',
#  'Lost Me (with RealestK)',
#  'Time Piece (feat. Lil Durk)',
#  'Kevin’s Heart',
#  'Lock On Me (with Travis Scott & Future)',
#  'Los Dioses',
#  'Mr. Morale',
#  'AIGHT (feat. Shelley FKA DRAM)',
#  'Lleca',
#  'Señor Miedo',
#  'Soy Peor - Remix',
#  'Poblado - Remix',
#  'Out for the Night - Live',
#  'Bring You Down',
#  'Captain Crunch (feat. Babyface Ray, Sada Baby, & Icewear Vezzo)',
#  'Tell Me U Luv Me (with Trippie Redd)',
#  'Mood (feat. Zacari)',
#  '5% TINT',
#  'Chasing Marrakech',
#  'Handsome And Wealthy',
#  'Blanco',
#  'Replace Me (feat. Big Sean & Don Toliver)',
#  'Yonaguni',
#  'Malos Ratos',
#  'Top Down On Da NAWF',
#  'Innocence (feat AlunaGeorge)',
#  'These Walls',
#  'Motivation',
#  'See You Again (feat. Kali Uchis)',
#  'None To Me',
#  'Bella-K (feat. Zion & Randy)',
#  "I'm Ready For You",
#  'Smile (with The Weeknd)',
#  '28',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Efecto',
#  'Lleca',
#  'Politics',
#  'History',
#  'HOUSTONFORNICATION',
#  'Gore',
#  'Tarot',
#  'blood on the leaves',
#  'Wu-Tang Forever',
#  'Life Letters',
#  '100',
#  'Lithuania (feat. Travis Scott)',
#  'slop',
#  'Blastoff (feat. Juice Wrld & Trippie Redd)',
#  'Sin Filtro',
#  'FEEL.',
#  'Atrapado en un Sueño',
#  'Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)',
#  'Darte Remix',
#  'Held Me Down',
#  'Over The Top (feat. Drake)',
#  'Ski Mask',
#  '28 Gramos',
#  'Ghetto Star',
#  'Te Robaré',
#  '23',
#  'Super Mario World',
#  'Planet Rock',
#  'Not the Same',
#  'Condones',
#  'One, Two Step (feat. Missy Elliott)',
#  'Big Shot (with Travis Scott)',
#  'beibs in the trap',
#  'Por Mi Reggae Muero 2020',
#  'ball w/o you',
#  'Watch (feat. Lil Uzi Vert & Kanye West)',
#  'Lovers Anonymous',
#  'La Maria',
#  'POCKET ROCKET',
#  'Same Girl (with Usher)',
#  'FWM',
#  '¿Cual Es Tu Plan?',
#  'Too Many Problems',
#  'Water (feat. Lil Baby)',
#  'Hot Hands',
#  'Tu Lo Sabes',
#  'PARA SIEMPRE',
#  'Ms. New Booty',
#  'Euphoria (feat. Travis Scott & Kaash Paige)',
#  'Teenage Fever',
#  'It Was A Good Day',
#  'fue mejor (feat. SZA)',
#  '23 Preguntas',
#  'Heaven Or Hell',
#  'Te Boté - Remix',
#  'Mo Bamba',
#  'Start This Shit Off Right (feat. Ashanti & Mack Maine)',
#  'YO LE LLEGO',
#  'I Keep Calling',
#  'Dedicate',
#  '1134',
#  'La Negra Tomasa - Tema Remasterizado',
#  'The Motion',
#  'How You Feel',
#  'fue mejor (feat. SZA)',
#  '6 Man',
#  'Rumba',
#  'Vida Buena',
#  'Out The Mud',
#  'Even Steven',
#  'Numb Numb Juice',
#  'I Hate U',
#  'Harleys In Hawaii',
#  'Ay Caramba',
#  'Ugotme',
#  'In and Out',
#  'Need to Know',
#  'Feeling Good Today',
#  'Shea Butter Baby (with J. Cole)',
#  'All Me',
#  'A-Team',
#  'Not You Too (feat. Chris Brown)',
#  'Super Rich Kids',
#  'In For It',
#  'Extasy',
#  'Malos Ratos',
#  'Hi This Is Flume',
#  'EL HOMBRE PERFECTO',
#  'Como Llora',
#  'HIDEOUT (feat. Fijimacintosh)',
#  'Special Remix (feat. Moneybagg Yo)',
#  'No Complaints',
#  'Hoodie',
#  'changes',
#  'Babystar',
#  'Dior',
#  'Powerglide (feat. Juicy J) - From SR3MM',
#  'Estrés Postraumático',
#  'BILLY',
#  'Rose Golden',
#  'Hype',
#  'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) - Remix',
#  'Hay Que Hacer Dinero',
#  'A Day Without a Mexican',
#  'Papi’s Home',
#  'Stay Awake',
#  'Privileged Rappers',
#  'Enjoy Yourself (feat. Karol G)',
#  'Killing Me Softly With His Song',
#  'too far close',
#  'No More (feat. Travis Scott, Kodak Black & 21 Savage)',
#  'too far close',
#  'The Weekend - Funk Wav Remix',
#  'Habit - Blood Cultures Remix',
#  'GIVENCHY',
#  'Desnudarte',
#  'Preparado',
#  'Abajo y Arriba (with Juhn)',
#  'Know Me',
#  '7 Min Freestyle',
#  'Wassup',
#  'Pelo Alborotau',
#  'Los Rompediskoteca',
#  'Dark Knight Dummo (Feat. Travis Scott)',
#  'Buttered Up',
#  'Impossible',
#  'New Feeling',
#  'Projects',
#  'Faith (feat. Quavo)',
#  'Honest (feat. Don Toliver)',
#  'Punto y Aparte',
#  'Satisfacción',
#  'Still Here',
#  'P2',
#  'durag activity (with Travis Scott)',
#  'RD',
#  'Leray',
#  'Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings)',
#  'Thinkin (feat. Anuel AA, Bad Bunny & Future)',
#  'Tap (feat. Meek Mill)',
#  'Go Loko',
#  'MODO DEPRE :(',
#  'After Hours',
#  'Que Es Esto?',
#  'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)',
#  'What You Need - Original',
#  'Sno Cone (feat. Quavo & Gucci Mane)',
#  'Experimento 01',
#  'Obsesion (No Es Amor) (feat. Baby Bash)',
#  'Free Porn Cheap Drugs',
#  'Hardest To Love',
#  'Acting Like',
#  'Love... (Her Fault) [feat. Bryson Tiller]',
#  'Bubalu',
#  'When I Talk',
#  'Insane',
#  'Closed On Sunday',
#  'Marinero',
#  'Stupid Me',
#  'Culo Chapa (feat. La Perversa, Quimico Ultra Mega & Haraca Kiko)',
#  'Sitting In The Corner (feat. Adriel Favela & Kacey Musgraves)',
#  'Sukutubla',
#  'Enjoy Yourself (feat. Karol G)',
#  "Can't Have Everything",
#  'Dispuesto (feat. Ozuna)',
#  'Ice Melts',
#  'A Solas (House)',
#  'NC-17',
#  'La Corriente',
#  'Mi Favorita',
#  'Scotty Pippen',
#  'Nothings Into Somethings',
#  "Bria's Interlude (feat. Omarion)",
#  'I Like That',
#  'Ecdysis',
#  "Don't Rush - Remix",
#  'Te Boté II',
#  'Enseñame',
#  "King's Dead (with Kendrick Lamar, Future & James Blake)",
#  'Alone Again',
#  'After Party',
#  'Dictadura',
#  "It's Officially Done",
#  'Drug Dealer',
#  'COMO UN BEBÉ',
#  'Never Know',
#  'Bendición Mami',
#  'KANGA',
#  'Hella Fun (feat. Jay Anthony)',
#  'VIDA LOCA',
#  'Famous',
#  'Mile High (feat. Travis Scott & Metro Boomin)',
#  'Ring (feat. Young Thug)',
#  '"BOP"',
#  'En La Disco Revela',
#  'Faneto',
#  "King's Dead (with Kendrick Lamar, Future & James Blake)",
#  'Limoncello',
#  "Put Me on Somethin'",
#  'Audi.',
#  'Z4L (with Bari & Jay2)',
#  'Gore',
#  'Fuck It up (feat. Yg)',
#  'Feel The Love',
#  'Inmortal',
#  'BIZCOCHITO',
#  'Falling For You',
#  'Said Sum (feat. City Girls & DaBaby) - Remix',
#  'Safari',
#  'Shut up My Moms Calling',
#  'Tetris',
#  'Keep Calling',
#  'L.N.E.M. (GATA) (feat. Kapla y Miky, Philip Ariaz & Blessd)',
#  'On Top (feat. T.Shirt)',
#  'The Birds Pt. 1',
#  'Me Gusta Tanto',
#  'De Lao A Lao: Turreo Sessions #5 - Remix',
#  'Chupable',
#  'Splashin',
#  'Tarot',
#  'Drop the Game',
#  'How You Feel',
#  'Monte Carlo (feat. WET)',
#  'You Never Know',
#  'Desnudarte',
#  'Lucky You (feat. Joyner Lucas)',
#  'Porsches In The Rain',
#  'If You Let Me',
#  '11 PM',
#  'Still',
#  'El JP',
#  'Baila Conmigo (feat. Kelly Ruiz)',
#  'Fighting Demons',
#  'Si Se Da - Remix',
#  'Donde Quieres',
#  'la luz(Fín)',
#  'Bonjour (feat. Summer Walker)',
#  'Un Beso',
#  'De Lao A Lao: Turreo Sessions #5 - Remix',
#  'Ball in Peace (Outro)',
#  'Views',
#  'THat Part - Black Hippy Remix',
#  'Lemonade',
#  'Leave The Door Open',
#  '3AM (From "Animal Crossing: Wild World") [Cover]',
#  '42.26',
#  'Duvibes',
#  'Cuántas veces',
#  'Te Extraño',
#  'Vivir Bailando',
#  'El JP',
#  'Romeo & Juliet',
#  'NO RAP KAP (feat. Trippie Redd)',
#  'Places',
#  'Nuevo',
#  'Por Mi Reggae Muero 2020',
#  'Drink To This',
#  'Wicked Freestyle',
#  'BELIEVE (feat. Don Toliver)',
#  'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) - Remix',
#  'Instagram',
#  'EYE ON IT',
#  'High Beams',
#  'Invincible',
#  "Megan's Piano",
#  'Wow.',
#  'Decadent',
#  'Black Privilege',
#  'Faithful',
#  'Controlla',
#  'La Difícil',
#  'Hawái',
#  'Paris to Tokyo',
#  'Undo (Back To My Heart)',
#  'UN PESO',
#  'What You Need',
#  'Girls Need Love',
#  'Hasta Que Dios Diga',
#  'Woah Woah Woah',
#  'Miss The Rage (feat. Playboi Carti)',
#  'Kill Them All',
#  'Come Thru',
#  'Me Olvidare de Ti',
#  'No Idea',
#  'GEEKALEEK (feat. Cash Kidd)',
#  'Party Favors (feat. Young Thug)',
#  'Powerglide (feat. Juicy J)',
#  'Ezra',
#  'Wraith',
#  'Estás en Mí Pasado',
#  'Hit This Hard',
#  'Take a Chance (feat Little Dragon)',
#  'Easy (feat. 6LACK)',
#  'cocoa (with Don Toliver)',
#  '19',
#  'How Bout Now',
#  'Señor Miedo',
#  'Jump Out the Face (feat. Future)',
#  'For The Night (feat. Lil Baby & DaBaby)',
#  'HOW BOUT THAT?',
#  'Legacy (feat. Travis Scott & 21 Savage)',
#  'Get Money (feat. Junior M.A.F.I.A.) - 2007 Remaster',
#  'Juice (feat. YG)',
#  'Sticky',
#  'Amor Tirano',
#  'Mood (feat. Zacari)',
#  'U Sellin Dope (with Future)',
#  'SWM',
#  'NO MIENTEN',
#  'KICK (feat. 6ix9ine)',
#  'I Dance (feat. Duki & Cuco)',
#  'We Rising',
#  'House Key',
#  'Swipe Life (feat. Rick Ross)',
#  'X Ley (feat. Dei V) - Remix',
#  'Sigues Con El - Remix',
#  'TE MUDASTE',
#  'Bandoleros',
#  'SUSANA (Remix)',
#  'Shake The Room (feat. Quavo)',
#  'STOP TRYING TO BE GOD',
#  'Can’t Take A Joke',
#  'West Coast',
#  'Beast',
#  "Neu Roses (Transgressor's Song)",
#  'Duvibes',
#  'Chamber Of Reflection',
#  'Para Todos Mis Paisanos',
#  'Still',
#  'Chucky Cheese',
#  'Joro',
#  'DAMN HOMIE (feat. Lil Yachty)',
#  'WAKE UP',
#  'Is There Someone Else?',
#  'E-ER (feat. Lil Yachty)',
#  'Lamento Boliviano',
#  "I Can't Tell (feat. LAUREL)",
#  'Holdin On - Hermitude Remix',
#  'All Facts Not 1 Opinion (feat. Slimmy B & DaBoii)',
#  'Que Rica (Tocame)',
#  'Focus (feat. 21 Savage)',
#  'Monte Carlo (feat. WET)',
#  'El Perdedor',
#  'Futsal Shuffle 2020',
#  'Time Flies',
#  '90mh',
#  'Peloton',
#  'Thursday',
#  'you & me',
#  'El Velador',
#  'Mentiras',
#  'Bésame',
#  'Light Switch',
#  'The Birds Pt. 1',
#  'Familia (with Anuel Aa, feat. Bantu) - Spider-Man: Into the Spider-Verse',
#  'Some Minds (feat. Andrew Wyatt)',
#  'Sexo Sin Titulo (feat. Jay Wheeler & Lenny Tavárez)',
#  'Dark Hearted',
#  'Places',
#  'La Safaera (Megamix)',
#  'Pound Cake / Paris Morton Music 2',
#  'Marinero',
#  'INVENTED IT',
#  'Too Good',
#  'Dembow 2020',
#  'Saint',
#  'Supastars',
#  'Grapes Alla Vodka - Salva Remix',
#  'Lies (feat. Ty Dolla $ign & YG)',
#  'Dos Mil 16',
#  'Places',
#  'Todo Bien',
#  'Hedonismo',
#  'Love & Drugz II',
#  'See You Again (feat. Kali Uchis)',
#  '...And To Those I Love, Thanks For Sticking Around',
#  'ALL I NEED (feat. Drake)',
#  'Summers Over Interlude',
#  'SAL DE MI CABEZA',
#  'Aullando',
#  'Acting Like',
#  'Everybody Dies In Their Nightmares',
#  'Mood',
#  'Nibiru',
#  'Essence (feat. Justin Bieber & Tems)',
#  'El Telefono',
#  'Luv Drunk',
#  'Free (Outro)',
#  'Icon',
#  'ZEZE (feat. Travis Scott & Offset)',
#  'Beautiful',
#  'LENTITO',
#  '712PM',
#  'Might as Well',
#  'Guatauba',
#  'Squidwards Nose (feat. Kg Prince)',
#  'Sunbathe',
#  'Un Coco',
#  "I'm Ready For You",
#  'Zoo York (feat. Fivio Foreign & Pop Smoke)',
#  'Solita',
#  'Ella Me Levanto',
#  'Para Todos Mis Paisanos',
#  'RLNDT',
#  'Water (feat. Lil Baby)',
#  'Casper',
#  'Oye Mujer',
#  'El Deportivo',
#  'Do It To It',
#  'Subimos de Rango',
#  'HOTEL LOBBY (Unc & Phew)',
#  'My Love (feat. T.I.)',
#  'We Rising',
#  'BUBBLE GUM',
#  '"BOP"',
#  'Exchange',
#  'TR666',
#  'Champagne Shots',
#  'N95',
#  'Vibe',
#  'Delincuente',
#  '2 Vaults (feat. Lil Yachty)',
#  'Rest in Peace',
#  'She Miss Me (feat. Rich the Kid)',
#  "LET'S PRAY (feat. Don Toliver & Travis Scott)",
#  'What’s New',
#  'Over',
#  'Like Water (feat. MNDR)',
#  'West Coast',
#  'Virtual Fish Market',
#  'All Me',
#  'Rakataka',
#  'BULLETPROOF (feat. Jay 305)',
#  'Amorfoda',
#  'Let It All Work Out',
#  "Flight's Booked",
#  'Tie That Binds',
#  'Cardigan',
#  'PRBLMS',
#  'RLNDT',
#  'Somo Así',
#  'Química (feat. The Martinez Brothers)',
#  'Feliz de Mentira',
#  'Amor Tirano',
#  'A Mi Si Me Gusta',
#  'Flex Up (feat. Future & Playboi Carti)',
#  'SLOW DANCING IN THE DARK',
#  'Rasta Barbie (Remix)',
#  'Jaigantic (Galimatias Remix)',
#  'Lose You',
#  'IMY2 (with Kid Cudi)',
#  'No Guidance (feat. Drake)',
#  'Súbelo',
#  'Scotty Pippen',
#  'Even Steven',
#  'Betrayal (feat. Drake)',
#  'La 2blea',
#  "Can't Get Enough",
#  'Understand',
#  'Lay Me Down - Flume Remix',
#  'Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#  'Ugotme',
#  'Fruit Salad',
#  'QUE PRETENDES',
#  'Always Forever',
#  'His & Hers (feat. Don Toliver, Lil Uzi Vert & Gunna)',
#  'MOOO!',
#  'Whip (feat. Travis Scott)',
#  'Como Antes',
#  'Top 5 (feat. Playboi Carti)',
#  'Love & Drugz II',
#  '100 Años',
#  'Levels',
#  'Psycho',
#  'Get It Together',
#  'Circo Loco',
#  'Saucy',
#  'Ki (feat. Daniel Habif)',
#  'Diplomatic Immunity',
#  'Santal 33',
#  'I Am',
#  "Stunting Ain't Nuthin (feat. Slim Jxmmi & Young Dolph)",
#  'T-Shirt',
#  'Playing Games (with Bryson Tiller) - Extended Version',
#  'THE NEWS',
#  'The Mantra - From "Creed II: The Album"',
#  'Miss me',
#  'Faucet Failure',
#  'Ezra',
#  'BLOOD.',
#  'The Big Unknown (From "Widows")',
#  'Vixen',
#  'Big Boy Diamonds (feat. Kodak Black & London on Da Track)',
#  'Jill (Sumn Real)',
#  'Stay Schemin',
#  'Water (Drowning Pt. 2) [feat. Kodak Black]',
#  'Nadie Como Tú',
#  'Last Forever (feat. Rick Ross & Snoop Dogg)',
#  'Why You Crying Mama',
#  'Sky Walker (feat. Travis Scott)',
#  'Feds',
#  'Tu Vecina (feat. Ty Dolla $ign)',
#  'Plan A',
#  'Vibe',
#  'Me Olvidare de Ti',
#  'Dos Uno Nueve (219)',
#  'Con La Brisa',
#  'Vanish',
#  'Tequila Shots',
#  'blood on the leaves',
#  'Te Ire A Buscar',
#  'Feel',
#  'So Good (& Metro Boomin)',
#  'Nasty',
#  'Black & Chinese',
#  'Te Boté II',
#  'Anti',
#  'La Única - Sprite Limelight',
#  "I'm Not The Only One",
#  'Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#  'Bonita',
#  'Fly',
#  'Undo (Back To My Heart)',
#  'Don',
#  'Tumbados En Miami',
#  'AL CAPONE',
#  'You Better Move',
#  'On BS',
#  'Like a Tattoo',
#  'Soy El Diablo - Remix',
#  'La Mamá de la Mamá',
#  'Stupid Me',
#  'WORKIN ME',
#  'Mi Favorita',
#  'Nonstop',
#  'Escápate Conmigo',
#  "Pa' Que La Pases Bien",
#  'Lift Me Up - From Black Panther: Wakanda Forever - Music From and Inspired By',
#  'PUSSY MONEY FAME',
#  'Nasty',
#  'Stan By Me',
#  'Luv (sic)',
#  'MOOO!',
#  'Qué Chimba',
#  'Hold Your Breath (feat. Gunna)',
#  'Whole Brick',
#  'Selah',
#  'untitled 07 | 2014 - 2016',
#  'Nothing Compares - Bonus Track',
#  'Holy Grail',
#  'Breath Control (feat. Wiz Khalifa)',
#  'Felices los 4',
#  'Superman',
#  'Quickie',
#  "Since '84",
#  'I WANNA SEE SOME ASS (feat. jetsonmade)',
#  'Lies (feat. Ty Dolla $ign & YG)',
#  'Lo Se',
#  'Amor Tirano',
#  'Love & Loyalty (Believe)',
#  'Deep End Freestyle',
#  'Floating (feat. 21 Savage)',
#  'All Girls Are The Same',
#  'Until I Bleed Out',
#  'Safeguard',
#  'Miss Me',
#  'Seek & Destroy',
#  'Hold Your Breath (feat. Gunna)',
#  'Sleepy Hollow',
#  'changes',
#  'The Adventures Of Stoney Bob (ft. Kajo, Slaydro, Big Lenbo)',
#  'De La Calle (Remix)',
#  'Coaster',
#  'One Up',
#  'Medusa',
#  'Smile (with The Weeknd)',
#  'Leray',
#  'Overtime (feat. Sebastian Reynoso & KYLE)',
#  'Champion (feat. Travis Scott)',
#  'GOD.',
#  'Piensas en Mí',
#  'No Te Creo',
#  'See Me (Step Up: Season 3, Original Soundtrack)',
#  'Something Foreign',
#  'Dimelo',
#  'High Highs to Low Lows',
#  'Nasty',
#  'Señor Miedo',
#  'BUBBLE GUM',
#  'Bounce Out With That Remix (feat. Machine Gun Kelly)',
#  'you & me',
#  'Top Off',
#  'Die For You',
#  '3am',
#  'YOSEMITE',
#  'Casper',
#  'Where U From',
#  'Busca un Culo',
#  "Don't Let Me Down (feat. Khalid)",
#  'Paper Planes',
#  'La H',
#  'Keraunos',
#  '4422',
#  'Holdin On - Hermitude Remix',
#  'Staccato',
#  'Black Panther',
#  'Griztronics',
#  'Mi Vicio',
#  'Excitement',
#  'Bagre',
#  'Chendo',
#  'Mood',
#  'Quickie',
#  'HIGHEST IN THE ROOM',
#  "Don't Miss It",
#  'Soul Searching',
#  'Chall Ready Know',
#  'Need to Know',
#  'LOSE IT (feat. Lil Baby)',
#  '44 Bars',
#  'Señor Miedo',
#  'JAPAN',
#  '3',
#  'Twilight City',
#  'La Jumpa',
#  'Have A Nice Day',
#  'Babystar',
#  'Flea Market',
#  'ULTRA VIOLET',
#  'Blastoff (feat. Juice Wrld & Trippie Redd)',
#  'No Less',
#  'I Keep Calling',
#  'Ay, DiOs Mío!',
#  'No Digas Mi Nombre',
#  'Drugz',
#  'Desnudarte',
#  'I Remember',
#  "What's Up (feat. Jagged Edge)",
#  'Final Fantasy',
#  'You',
#  'Love Me',
#  'Christopher Walking',
#  ...]
